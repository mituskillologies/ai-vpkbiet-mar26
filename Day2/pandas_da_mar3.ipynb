# %% [markdown]
# ## Series

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([12, 34, 56, 78, 10])

# %%
s
# Out:
# 0    12
# 1    34
# 2    56
# 3    78
# 4    10
# dtype: int64

# %%
s[2]
# Out:
# np.int64(56)

# %%
s = pd.Series([12, 34, 56, 78, 10], index= range(100, 105))
s
# Out:
# 100    12
# 101    34
# 102    56
# 103    78
# 104    10
# dtype: int64

# %%
s[103]
# Out:
# np.int64(78)

# %% [markdown]
# ## Dataframes

# %%
roll = pd.Series([1, 2, 3, 4, 5])
name = pd.Series(['geet', 'ankit', 'ravi', 'kritika', 'natasha'])
marks = pd.Series([78, 79, 67, 81, 80])

# %%
df = pd.DataFrame({
    'roll': roll,
    'name': name,
    'marks': marks
})

# %%
df
# Out:
#    roll     name  marks
# 0     1     geet     78
# 1     2    ankit     79
# 2     3     ravi     67
# 3     4  kritika     81
# 4     5  natasha     80

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'marks'], dtype='object')

# %%
"""
url => https://mitu.co.in/dataset

this will redirect u to drive folder containing datasets
download datasets starting with student*... eg... student.csv, student1.csv

after downloading put them into the same directory where ur jupyter notebook
files are 
""";

# %%
pwd
# Out:
# '/home/aditya/VPBKIET_Mar2_2026/Day2'

# %%
df = pd.read_csv("student.csv")
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.shape
# Out:
# (10, 5)

# %%
# student1.csv

# %%
df = pd.read_csv("student1.csv")
df
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
col = ["id", "name", "class", "grade", "age"]

# %%
df = pd.read_csv("student1.csv", names= col)
df
# Out:
#    id     name class  grade  age
# 0   1     anil    TE  56.77   22
# 1   2     amit    TE  59.77   21
# 2   3   aniket    BE  76.88   19
# 3   4  ajinkya    TE  69.66   20
# 4   5     asha    TE  63.28   20
# 5   6   ayesha    BE  49.55   20
# 6   7     amar    BE  65.34   19
# 7   8    amita    BE  68.33   23
# 8   9     amol    TE  56.75   20
# 9  10    anmol    BE  78.66   21

# %%
# student3.tsv

# %%
df = pd.read_csv("student3.tsv", sep = '\t')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df = pd.read_csv("student.csv")
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20],
#        [6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19],
#        [8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20],
#        [10, 'anmol', 'BE', 78.66, 21]], dtype=object)

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
# slicing

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[3:6, 1:4]
# Out:
#       name class  marks
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55

# %%
df.iloc[[3, 4, 6], 0:2]
# Out:
#    roll     name
# 3     4  ajinkya
# 4     5     asha
# 6     7     amar

# %%
df.iloc[[2, 3, 4, 6, 7], [1, 3 , 4]]
# Out:
#       name  marks  age
# 2   aniket  76.88   19
# 3  ajinkya  69.66   20
# 4     asha  63.28   20
# 6     amar  65.34   19
# 7    amita  68.33   23

# %%
df.loc[:, 'class']
# Out:
# 0    TE
# 1    TE
# 2    BE
# 3    TE
# 4    TE
# 5    BE
# 6    BE
# 7    BE
# 8    TE
# 9    BE
# Name: class, dtype: object

# %%
type(df.loc[:, 'class'])
# Out:
# pandas.core.series.Series

# %%
df['class']
# Out:
# 0    TE
# 1    TE
# 2    BE
# 3    TE
# 4    TE
# 5    BE
# 6    BE
# 7    BE
# 8    TE
# 9    BE
# Name: class, dtype: object

# %%
df[['class', 'name']]
# Out:
#   class     name
# 0    TE     anil
# 1    TE     amit
# 2    BE   aniket
# 3    TE  ajinkya
# 4    TE     asha
# 5    BE   ayesha
# 6    BE     amar
# 7    BE    amita
# 8    TE     amol
# 9    BE    anmol

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19
# 4     5    asha    TE  63.28   20
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.drop([3, 4, 6])
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19
# 5     6  ayesha    BE  49.55   20
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.drop('class', axis = 1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
# function and methods on series

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['marks'].mean()
# Out:
# np.float64(64.499)

# %%
df['marks'].sum()
# Out:
# np.float64(644.9899999999999)

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.startswith('an')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['roll'] = df['roll'] + 100

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
gender = ['m', 'm', 'm', 'm', 'f', 'f', 'm', 'f', 'm', 'm']

# %%
df['gender'] = gender

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0   101     anil    TE  56.77   22      m
# 1   102     amit    TE  59.77   21      m
# 2   103   aniket    BE  76.88   19      m
# 3   104  ajinkya    TE  69.66   20      m
# 4   105     asha    TE  63.28   20      f
# 5   106   ayesha    BE  49.55   20      f
# 6   107     amar    BE  65.34   19      m
# 7   108    amita    BE  68.33   23      f
# 8   109     amol    TE  56.75   20      m
# 9   110    anmol    BE  78.66   21      m

# %%
# create a column ->   cgpa
# values should be->   marks/10 + 1.5

# %%
df['cgpa'] = df['marks'] / 10 + 1.5

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106   ayesha    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
gr = df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr['marks'].mean()
# Out:
# class
# BE    67.752
# TE    61.246
# Name: marks, dtype: float64

# %%
gr.get_group('BE')
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   103  aniket    BE  76.88   19      m  9.188
# 5   106  ayesha    BE  49.55   20      f  6.455
# 6   107    amar    BE  65.34   19      m  8.034
# 7   108   amita    BE  68.33   23      f  8.333
# 9   110   anmol    BE  78.66   21      m  9.366

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106   ayesha    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.sort_values(by = 'marks')
# Out:
#    roll     name class  marks  age gender   cgpa
# 5   106   ayesha    BE  49.55   20      f  6.455
# 8   109     amol    TE  56.75   20      m  7.175
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 4   105     asha    TE  63.28   20      f  7.828
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 2   103   aniket    BE  76.88   19      m  9.188
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.sort_values(by = 'marks', ascending= False)
# Out:
#    roll     name class  marks  age gender   cgpa
# 9   110    anmol    BE  78.66   21      m  9.366
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 7   108    amita    BE  68.33   23      f  8.333
# 6   107     amar    BE  65.34   19      m  8.034
# 4   105     asha    TE  63.28   20      f  7.828
# 1   102     amit    TE  59.77   21      m  7.477
# 0   101     anil    TE  56.77   22      m  7.177
# 8   109     amol    TE  56.75   20      m  7.175
# 5   106   ayesha    BE  49.55   20      f  6.455

# %%
# boolean filtering

# %%
df[df['marks'] > 65]
# Out:
#    roll     name class  marks  age gender   cgpa
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df[(df['marks'] > 65) & (df['class'] == 'BE')]
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   103  aniket    BE  76.88   19      m  9.188
# 6   107    amar    BE  65.34   19      m  8.034
# 7   108   amita    BE  68.33   23      f  8.333
# 9   110   anmol    BE  78.66   21      m  9.366

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106   ayesha    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.drop(['gender', 'cgpa'], axis = 1, inplace = True)

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
# create a dataframe called df1 having columns -> roll, gender, cgpa
# roll column should be having same values as that of roll column of df

# %%
df1 = pd.DataFrame({
    'roll': df['roll'],
    'gender': gender,
    'cgpa': df['marks']/10 + 1.5
})

# %%
df1
# Out:
#    roll gender   cgpa
# 0   101      m  7.177
# 1   102      m  7.477
# 2   103      m  9.188
# 3   104      m  8.466
# 4   105      f  7.828
# 5   106      f  6.455
# 6   107      m  8.034
# 7   108      f  8.333
# 8   109      m  7.175
# 9   110      m  9.366

# %%
pd.merge(df, df1, on = 'roll')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106   ayesha    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df2 = pd.read_csv("student5.csv")
df2
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
pd.concat([df, df2], ignore_index= True)
# Out:
#     roll     name class  marks  age
# 0    101     anil    TE  56.77   22
# 1    102     amit    TE  59.77   21
# 2    103   aniket    BE  76.88   19
# 3    104  ajinkya    TE  69.66   20
# 4    105     asha    TE  63.28   20
# 5    106   ayesha    BE  49.55   20
# 6    107     amar    BE  65.34   19
# 7    108    amita    BE  68.33   23
# 8    109     amol    TE  56.75   20
# 9    110    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %%
x = pd.concat([df, df2], ignore_index= True)
x.to_csv('op.csv', index= False)

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.read_csv("student3.csv")
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    16 non-null     int64
#  1   name    16 non-null     object
#  2   class   15 non-null     object
#  3   marks   14 non-null     float64
#  4   age     14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 772.0+ bytes

# %%
df['name']
# Out:
# 0        anil
# 1        amit
# 2      aniket
# 3     ajinkya
# 4        asha
# 5      ayesha
# 6        amar
# 7       Amita
# 8        amol
# 9        amol
# 10      anmol
# 11     surbhi
# 12      Sujay
# 13    subhash
# 14     sachin
# 15    shalini
# Name: name, dtype: object

# %%
df['name'] = df['name'].str.title()

# %%
df
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 4      5     Asha    TE   63.28   NaN
# 5      6   Ayesha    BE     NaN  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 9      9     Amol    TE   56.75  20.0
# 10    10    Anmol    BE   78.66   NaN
# 11    11   Surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    be   88.45  21.0
# 14    14   Sachin   NaN   59.33  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df['class'] = df['class'].str.upper()

# %%
df
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 4      5     Asha    TE   63.28   NaN
# 5      6   Ayesha    BE     NaN  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    BE   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 9      9     Amol    TE   56.75  20.0
# 10    10    Anmol    BE   78.66   NaN
# 11    11   Surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    BE   88.45  21.0
# 14    14   Sachin   NaN   59.33  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df['marks ']
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5       NaN
# 6     65.34
# 7     68.33
# 8     56.75
# 9     56.75
# 10    78.66
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks , dtype: float64

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks ', 'age'], dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df['marks']
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5       NaN
# 6     65.34
# 7     68.33
# 8     56.75
# 9     56.75
# 10    78.66
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks, dtype: float64

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
True + True + False
# Out:
# 2

# %%
df.drop_duplicates(inplace = True)

# %%
# missing values

# %%
df.count()
# Out:
# roll     15
# name     15
# class    14
# marks    13
# age      13
# dtype: int64

# %%
df.isnull().sum()
# Out:
# roll     0
# name     0
# class    1
# marks    2
# age      2
# dtype: int64

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
# deleting the rows having null values

df.dropna()
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df['marks'].fillna(100)
# Out:
# 0      56.77
# 1      59.77
# 2      76.88
# 3      69.66
# 4      63.28
# 5     100.00
# 6      65.34
# 7      68.33
# 8      56.75
# 10     78.66
# 11    100.00
# 12     74.12
# 13     88.45
# 14     59.33
# 15     63.45
# Name: marks, dtype: float64

# %%
df['marks'].fillna(df['marks'].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     67.753077
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 10    78.660000
# 11    67.753077
# 12    74.120000
# 13    88.450000
# 14    59.330000
# 15    63.450000
# Name: marks, dtype: float64

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.ffill()
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  63.28  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66  20.0
# 11    11   Surbhi    TE  78.66  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin    BE  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.bfill(inplace = True)

# %%
df.isnull().sum()
# Out:
# roll     0
# name     0
# class    0
# marks    0
# age      0
# dtype: int64
