# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([10, 13, 19, 27, 33, 39, 41])
y = np.array([15, 18, 24, 33, 37, 42, 48])
z = np.array([50, 44, 40, 35, 29, 22, 15])

# %%
# line plot

# %%
plt.title("trend analysis")
plt.xlabel("x-values")
plt.ylabel("y-values")

plt.plot(x, y, marker = 'o', mfc = 'red', color = 'purple',
        ls= '--');
plt.grid()
# markers -> *, o, <, ^, >, H

# %%
# barplot

# %%
df = pd.read_csv('student.csv')

tips = sns.load_dataset('tips')

# %%
df;

# %%
plt.title("student marks")
plt.xlabel("names")
plt.ylabel("marks")
plt.xticks(rotation = 45)

plt.bar(df['name'], df['marks'], color = 'black', 
               edgecolor = 'yellow');

plt.grid()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
plt.pie(tips['time'].value_counts(), 
        labels = tips['time'].value_counts().index,
       autopct= "%.2f", explode = [0, 0.2],
       shadow = True);

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
iris['species'] = le.fit_transform(iris['species'])

# %%
plt.figure(figsize=(12, 9))
plt.scatter(iris['sepal_width'], iris['sepal_length'],
           );

# %%
sns.scatterplot(x = 'sepal_width', y ='sepal_length',
               data = iris, hue = 'species');
