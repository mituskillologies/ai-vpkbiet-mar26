# %%
import numpy as np

# %%
a1 = np.array([12, 44.23, True, "ok", 63])

# %%
a1
# Out:
# array(['12', '44.23', 'True', 'ok', '63'], dtype='<U32')

# %%
a1[3]
# Out:
# np.str_('ok')

# %%
a1[3] = "changed"

# %%
a1
# Out:
# array(['12', '44.23', 'True', 'changed', '63'], dtype='<U32')

# %%
a2 = np.array([34, 5, 6, 77.88, 10, 10, 10])

# %%
a2
# Out:
# array([34.  ,  5.  ,  6.  , 77.88, 10.  , 10.  , 10.  ])

# %%
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 show()
#
# NameError: name 'show' is not defined

# %%
import mod1

# %%
mod1.show()
# Out:
# hello
# ok
# zzzzzz

# %%
help(mod1)
# Out:
# Help on module mod1:
#
# NAME
#     mod1
#
# FUNCTIONS
#     show()
#
# FILE
#     /home/aditya/VPBKIET_Mar2_2026/mod1.py

# %%
a1
# Out:
# array(['12', '44.23', 'True', 'changed', '63'], dtype='<U32')

# %%
a1.ndim
# Out:
# 1

# %%
a1.shape
# Out:
# (5,)

# %%
a1.size
# Out:
# 5

# %%
a1
# Out:
# array(['12', '44.23', 'True', 'changed', '63'], dtype='<U32')

# %%
a1[1:4]
# Out:
# array(['44.23', 'True', 'changed'], dtype='<U32')

# %%
# speed of list and array

# %%
l = list(range(1000000))
arr = np.array(l)

# %%
import time

# %%
time.time()
# Out:
# 1772446054.366155

# %%
start_time = time.time()
newarr = arr * 2
time_arr = time.time() - start_time
print("time taken by an array:", time_arr)
# Out:
# time taken by an array: 0.0016350746154785156

# %%
newarr
# Out:
# array([      0,       2,       4, ..., 1999994, 1999996, 1999998],
#       shape=(1000000,))

# %%
start_time = time.time()
newli = [i*2 for i in l]
time_list = time.time() - start_time
print("time taken by an array:", time_list)
# Out:
# time taken by an array: 0.025464296340942383

# %%
time_list/time_arr
# Out:
# 15.573782443861184
